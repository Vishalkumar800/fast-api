# %% [markdown]
# # Path parameter
#
# `@app.get("/users/{id}")`
#
# ### here id is your path parameter
#
#
# # Query Parameter
#
# `Query use krne me use hota search and yeah apne hmsesha parmas me jata hai `

# %% [markdown]
# ## Response Model class
#
# ```
#
# from fastapi import FastAPI
# from testdata import employees
# from pydantic import BaseModel
#
# app = FastAPI()
#
# class ResponseModelClass(BaseModel):
#     id: int
#     name: str
#     age: int
#     department: str
#     salary: float
#
# @app.get("/", response_model=list[ResponseModelClass])
# def home():
#     return employees
#
#
# Test data me jake tum dekh skhte ho employee data
#
# ```
#
# ## Response Mpdel ka use kiya jata hai kisi detail ho hide kne ke liye taki wo jb server data bheje toh na dikhe
#
# `Security Issues`

# %% [markdown]
# ## Service me apka jo bhi logic code hai api me kya kaise hoga wo sb aap services folder me likhte ho
